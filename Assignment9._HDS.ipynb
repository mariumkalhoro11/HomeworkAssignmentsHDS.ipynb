# %% [markdown]
# # Assignment 9 – HDS
#
# **Name:** Marium Kalhoro
# **Course:** PUBH 1142 – Health Data Science
# **Assignment:** Assignment 9

# %% [markdown]
# ## **Question 1: How do you import the pandas package in Python?**
#
# ```python
# import pandas as pd

# %% [markdown]
# ## **Question 2: What function do you use to read a CSV file in pandas?**
#
# ```python
# pd.read_csv("file.csv")
# ```

# %% [markdown]
# ## **Question 3: How do you display the first 5 rows of a DataFrame in pandas?**
#
# ```python
# df.head()
# ```

# %% [markdown]
# ## **Question 4: How do you calculate the mean of a column named Age in a DataFrame named df?**
#
# ```python
# df["Age"].mean()
# ```

# %% [markdown]
# ## **Question 5: How do you calculate the median of a column named Salary in a DataFrame named df?**
#
# ```python
# df["Salary"].median()
# ```

# %% [markdown]
# ## **Question 6: How do you calculate the standard deviation of a column named Score in a DataFrame named df?**
#
# ```python
# df["Score"].std()
# ```

# %% [markdown]
# ## **Question 7: How do you find the number of missing values in each column of a DataFrame named df?**
#
# ```python
# df.isnull().sum()
# ```

# %% [markdown]
# ## **Question 8: How do you calculate the correlation between Age and Salary in a DataFrame df?**
#
# ```python
# df["Age"].corr(df["Salary"])
# ```

# %% [markdown]
# ## **Question 9: How do you select a subset of a DataFrame df where Age is greater than 30?**
#
# ```python
# df[df["Age"] > 30]
# ```

# %% [markdown]
# ## **Question 10: How do you calculate the range of the Score column?**
#
# ```python
# df["Score"].max() - df["Score"].min()
# ```

# %% [markdown]
# ## **Question 11: How do you group by Department and calculate the mean Salary?**
#
# ```python
# df.groupby("Department")["Salary"].mean()
# ```

# %% [markdown]
# ## **Question 12: How do you group by Department and Job Title and count rows?**
#
# ```python
# df.groupby(["Department", "Job Title"]).size()
# ```

# %% [markdown]
# ## **Question 13: How do you find the maximum Age in each Department?**
#
# ```python
# df.groupby("Department")["Age"].max()
# ```

# %% [markdown]
# ## **Question 14: How do you create a frequency crosstab of Department and Job Title?**
#
# ```python
# pd.crosstab(df["Department"], df["Job Title"])
# ```

# %% [markdown]
# ## **Question 15: How do you create a crosstab showing mean Salary by Department and Job Title?**
#
# ```python
# pd.crosstab(df["Department"], df["Job Title"], values=df["Salary"], aggfunc="mean")
# ```
